# %%
import numpy as np
from functools import lru_cache
# %load_ext rich

# %%
@lru_cache()
def f(x):
    return 3*(x**2) - 4*x

# %%
for h in 10.0**np.arange(-1,-6,-1):
    print(f"h = {h:.5f}, limit = {(f(h+1)-f(1))/h}")
# Out:
# h = 0.10000, limit = 2.3000000000000043
# h = 0.01000, limit = 2.0299999999999763
# h = 0.00100, limit = 2.002999999999311
# h = 0.00010, limit = 2.0002999999979565
# h = 0.00001, limit = 2.0000300000155846
